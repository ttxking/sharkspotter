# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os
import re
import warnings
import joblib
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.applications.densenet import preprocess_input
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, log_loss, confusion_matrix
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from keras.utils import to_categorical
from keras.models import Model
from keras import backend as K
from PIL import Image

# Test shit
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from keras.applications.mobilenet import MobileNet
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
# Out:
# 2023-04-15 00:08:46.531074: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
warnings.filterwarnings("ignore")

# %%
def set_seed(seed):
  os.environ['TF_DETERMINISTIC_OPS'] = '1'
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)

# %%
set_seed(42)

# %%
image_dir = '../dataset/splited/shark_44/train'
test_dir = '../dataset/splited/shark_44/test'

# %%
def load_img(image_dir):
    list_images = []
    for label in os.listdir(image_dir):
        if label != '.DS_Store':
            for file in os.listdir(os.path.join(image_dir,label)):
                if re.search('jpg|JPG', file):
                    list_images.append(f"{image_dir}/{label}/{file}")
    return list_images

# %%
def extract_feature(list_images):
    features = []
    labels = []

    nb_features = 1920  
    features = np.empty((len(list_images), nb_features))

    for ind, image_path in enumerate(list_images):
        print('Processing %s...' % (image_path))
        img = image.load_img(image_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        features[ind,:] = np.squeeze(extractor_model.predict(x))
        labels.append(image_path.split('/')[-2])

    
    return features, labels

# %% [markdown]
# # DenseNet as feature extractor

# %%
base_model = DenseNet201(weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
extractor_model = Model(inputs=base_model.input, outputs=x)

# %%
train_images = load_img(image_dir)
features, labels = extract_feature(train_images)
# Out:
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811337414.jpg...
# 2023-04-15 00:08:54.596642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:54.596864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 3s 3s/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811341227.jpg...
# 2023-04-15 00:08:57.603387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:57.603610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 262ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C-amblyrhychos-ธวัชชัย1-1.jpg...
# 2023-04-15 00:08:57.932413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:57.932722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 271ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb11-1.jpg...
# 2023-04-15 00:08:58.324140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:58.324351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 258ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811339205.jpg...
# 2023-04-15 00:08:58.636659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:58.636884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 337ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb11-2.jpg...
# 2023-04-15 00:08:59.099280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:59.099580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 347ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb08.JPG...
# 2023-04-15 00:08:59.523528: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:59.523746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 309ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/14721.jpg...
# 2023-04-15 00:08:59.897622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:08:59.897869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 343ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C-amblyrhychos-ธวัชชัย2-1.jpg...
# 2023-04-15 00:09:00.301994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:00.302239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 331ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1123959.jpg...
# 2023-04-15 00:09:00.722123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:00.722563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 332ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb01.jpg...
# 2023-04-15 00:09:01.098812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:01.099036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 299ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811346085.jpg...
# 2023-04-15 00:09:01.459346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:01.459714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 492ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb03.jpg...
# 2023-04-15 00:09:02.004900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:02.005157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 330ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb02.jpg...
# 2023-04-15 00:09:02.379711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:02.380034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 265ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb06.jpg...
# 2023-04-15 00:09:02.682420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:02.682631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb12.jpg...
# 2023-04-15 00:09:03.016130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:03.016341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 238ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811333580.jpg...
# 2023-04-15 00:09:03.300954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:03.301229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 264ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C-amblyrhychos-ธวัชชัย1.jpg...
# 2023-04-15 00:09:03.622531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:03.622741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 244ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb07.JPG...
# 2023-04-15 00:09:03.930777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:03.930991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 237ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb11.JPG...
# 2023-04-15 00:09:04.321087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:04.321301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 260ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb05.JPG...
# 2023-04-15 00:09:04.650491: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:04.650734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 252ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C-amblyrhychos-ธวัชชัย2.jpg...
# 2023-04-15 00:09:04.956397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:04.956607: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 242ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb04.jpg...
# 2023-04-15 00:09:05.236405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:05.236622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 250ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/C.amb10.JPG...
# 2023-04-15 00:09:05.660448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:05.660634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 284ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/1435811335354.jpg...
# 2023-04-15 00:09:06.040433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:06.040667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 244ms/step
# Processing ../dataset/splited/shark_44/train/grey reef shark/fyu.jpg...
# 2023-04-15 00:09:06.329148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:06.329356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/train/great hammerhead/Sphyrna mokarran.jpg...
# 2023-04-15 00:09:07.105398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:07.105613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 266ms/step
# Processing ../dataset/splited/shark_44/train/great hammerhead/S.mok03.jpg...
# 2023-04-15 00:09:07.474887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:07.475100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/train/great hammerhead/S.mok02.jpg...
# 2023-04-15 00:09:07.765392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:07.765611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 248ms/step
# Processing ../dataset/splited/shark_44/train/great hammerhead/S.mok5.JPG...
# 2023-04-15 00:09:08.159409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:08.159626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 340ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (23).JPG...
# 2023-04-15 00:09:08.545638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:08.545872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 267ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/Sphyrna lewini4.jpg...
# 2023-04-15 00:09:09.362350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:09.362680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 305ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (19).JPG...
# 2023-04-15 00:09:09.741737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:09.741979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 266ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/IMG_1916.JPG...
# 2023-04-15 00:09:10.153892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:10.154110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 265ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (6).jpg...
# 2023-04-15 00:09:10.456473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:10.456683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (15).JPG...
# 2023-04-15 00:09:10.787268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:10.787556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 261ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (7).JPG...
# 2023-04-15 00:09:11.158101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:11.158327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 239ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/Sphyrna lewini3.jpg...
# 2023-04-15 00:09:12.027763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:12.027983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 248ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (18).JPG...
# 2023-04-15 00:09:12.464303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:12.464484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/240440.jpg...
# 2023-04-15 00:09:12.765832: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:12.766045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 260ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew00.jpg...
# 2023-04-15 00:09:13.063753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:13.063967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (22).JPG...
# 2023-04-15 00:09:13.495692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:13.495901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 248ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (13).JPG...
# 2023-04-15 00:09:13.846628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:13.846834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 264ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S-lew.jpg...
# 2023-04-15 00:09:14.167400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:14.167611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 248ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (25).JPG...
# 2023-04-15 00:09:14.455392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:14.455602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 263ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/11089.jpg...
# 2023-04-15 00:09:14.776570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:14.776790: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 265ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (24).JPG...
# 2023-04-15 00:09:15.080417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:15.080635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 267ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (12).JPG...
# 2023-04-15 00:09:15.414198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:15.414524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 301ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (11).JPG...
# 2023-04-15 00:09:15.773847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:15.774162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 259ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/240438.jpg...
# 2023-04-15 00:09:16.079838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:16.080067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/240439.jpg...
# 2023-04-15 00:09:16.375124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:16.375343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 261ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (27).JPG...
# 2023-04-15 00:09:16.675858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:16.676068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 260ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (26).JPG...
# 2023-04-15 00:09:16.977321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:16.977542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/11087.jpg...
# 2023-04-15 00:09:17.282728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:17.282938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 272ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (3).jpg...
# 2023-04-15 00:09:17.599066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:17.599295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/IMG_1920.JPG...
# 2023-04-15 00:09:18.003457: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:18.003671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (8).JPG...
# 2023-04-15 00:09:18.367959: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:09:18.368165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/train/scalloped hammerhead/S.lew (17).JPG...
# ...
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 318ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C.gri09.JPG...
# 2023-04-15 00:13:13.966176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:13.966428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 333ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_4619.JPG...
# 2023-04-15 00:13:14.434695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:14.434935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 327ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_4624.JPG...
# 2023-04-15 00:13:14.917922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:14.918420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 304ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_4618.JPG...
# 2023-04-15 00:13:15.379763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:15.380113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 282ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C. griseum (4).JPG...
# 2023-04-15 00:13:15.737361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:15.737639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 278ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2385.JPG...
# 2023-04-15 00:13:16.190209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:16.190433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 240ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C. griseum (11).JPG...
# 2023-04-15 00:13:16.505109: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:16.505431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 277ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2390.JPG...
# 2023-04-15 00:13:16.946819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:16.947052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2384.JPG...
# 2023-04-15 00:13:17.365337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:17.365570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2386.JPG...
# 2023-04-15 00:13:17.780877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:17.781103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 259ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2379.JPG...
# 2023-04-15 00:13:18.218493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:18.218727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C. griseum (3).JPG...
# 2023-04-15 00:13:18.535512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:18.535755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2387.JPG...
# 2023-04-15 00:13:18.943074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:18.943313: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 281ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2383.JPG...
# 2023-04-15 00:13:19.408362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:19.408591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 244ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C. griseum (2).JPG...
# 2023-04-15 00:13:19.725725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:19.725969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 342ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2382.JPG...
# 2023-04-15 00:13:20.269196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:20.269479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 323ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2380.JPG...
# 2023-04-15 00:13:20.752965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:20.753198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 261ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/C.gri07-1.jpg...
# 2023-04-15 00:13:21.059198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:21.059425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 274ms/step
# Processing ../dataset/splited/shark_44/train/grey bambooshark/IMG_2381.JPG...
# 2023-04-15 00:13:21.522530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:13:21.522812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 328ms/step

# %%
# Number of labels - 18
class_labels = os.listdir(image_dir)
if '.DS_Store' in class_labels:
    class_labels.remove('.DS_Store')
encoder_labels = LabelEncoder()
encoder_labels.fit(class_labels)
labels_numeric = encoder_labels.transform(labels)

# %%
X_train, X_val, y_train, y_val = train_test_split(features, labels_numeric, test_size=0.1, random_state=42)

# %%
test_img = load_img(test_dir)
X_test, y_test = extract_feature(test_img)
# Out:
# Processing ../dataset/splited/shark_44/test/grey reef shark/C.amb09.jpg...
# 2023-04-15 00:37:07.774412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:07.774648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 262ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/C.amblyrhynchos.jpg...
# 2023-04-15 00:37:08.135100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:08.135347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 256ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/14722.jpg...
# 2023-04-15 00:37:08.454229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:08.454474: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 274ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/1435811347971.jpg...
# 2023-04-15 00:37:08.794055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:08.794291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 268ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/14723.jpg...
# 2023-04-15 00:37:09.125873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:09.126206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 282ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/1435811342986.jpg...
# 2023-04-15 00:37:09.472000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:09.472400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 281ms/step
# Processing ../dataset/splited/shark_44/test/grey reef shark/1123945.jpg...
# 2023-04-15 00:37:09.813492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:09.813736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 340ms/step
# Processing ../dataset/splited/shark_44/test/great hammerhead/S.mok04.jpg...
# 2023-04-15 00:37:10.208985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:10.209301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 263ms/step
# Processing ../dataset/splited/shark_44/test/great hammerhead/Smok51.jpg...
# 2023-04-15 00:37:10.591142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:10.591396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 300ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/IMG_1917.JPG...
# 2023-04-15 00:37:11.050692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:11.050912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 300ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (14).JPG...
# 2023-04-15 00:37:11.431134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:11.431351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S-lew-ธวัชชชัย.jpg...
# 2023-04-15 00:37:11.741130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:11.741358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 256ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (29).jpg...
# 2023-04-15 00:37:12.057818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:12.058033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/11088.jpg...
# 2023-04-15 00:37:12.367476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:12.367695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 272ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (28).JPG...
# 2023-04-15 00:37:12.688149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:12.688538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 266ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (2).jpg...
# 2023-04-15 00:37:13.008370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:13.008663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 308ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (10).JPG...
# 2023-04-15 00:37:13.394744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:13.394966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 265ms/step
# Processing ../dataset/splited/shark_44/test/scalloped hammerhead/S.lew (21).jpg...
# 2023-04-15 00:37:13.828457: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:13.828684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/coral shark/A.mar051.jpg...
# 2023-04-15 00:37:14.165660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:14.165881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 322ms/step
# Processing ../dataset/splited/shark_44/test/coral shark/A.mar01.jpg...
# 2023-04-15 00:37:14.537206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:14.537481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 311ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_0955.JPG...
# 2023-04-15 00:37:14.930499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:14.930724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_0968.JPG...
# 2023-04-15 00:37:15.274690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:15.274936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 280ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/Carcharhinus leucas02.JPG...
# 2023-04-15 00:37:15.710858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:15.711101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 307ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_0952.JPG...
# 2023-04-15 00:37:16.103069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:16.103283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 298ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_0950.JPG...
# 2023-04-15 00:37:16.485135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:16.485352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 281ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_1837.JPG...
# 2023-04-15 00:37:16.941889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:16.942124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_1895.JPG...
# 2023-04-15 00:37:17.364480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:17.364723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 269ms/step
# Processing ../dataset/splited/shark_44/test/bull shark/IMG_0966.JPG...
# 2023-04-15 00:37:17.715413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:17.715722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 258ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_3.jpg...
# 2023-04-15 00:37:18.027046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:18.027276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 284ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_0_1.jpg...
# 2023-04-15 00:37:18.370370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:18.370619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 250ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_6.jpg...
# 2023-04-15 00:37:18.673466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:18.673715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 310ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/278647.jpg...
# 2023-04-15 00:37:19.066068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:19.066286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_6_1.jpg...
# 2023-04-15 00:37:19.371081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:19.371300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 290ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_1_0.jpg...
# 2023-04-15 00:37:19.719972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:19.720222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 313ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C-sor2.jpg...
# 2023-04-15 00:37:20.183512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:20.183797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 298ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor (21).JPG...
# 2023-04-15 00:37:20.710821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:20.711071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 277ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_1_1.jpg...
# 2023-04-15 00:37:21.050882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:21.051146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 264ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor.JPG...
# 2023-04-15 00:37:21.376900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:21.377160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 264ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_3_1.jpg...
# 2023-04-15 00:37:21.692138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:21.692376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_10.jpg...
# 2023-04-15 00:37:22.000242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:22.000459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 265ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor19.JPG...
# 2023-04-15 00:37:22.342364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:22.342571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 252ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor31.JPG...
# 2023-04-15 00:37:22.727420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:22.727604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 245ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/IMG_9069.JPG...
# 2023-04-15 00:37:23.031640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:23.031871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 258ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_7_0.jpg...
# 2023-04-15 00:37:23.345826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:23.346052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_29.jpg...
# 2023-04-15 00:37:23.646303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:23.646524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 244ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_28.jpg...
# 2023-04-15 00:37:23.941625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:23.941848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 242ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_7_1.jpg...
# 2023-04-15 00:37:24.234991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:24.235205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_16.jpg...
# 2023-04-15 00:37:24.537826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:24.538044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 252ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_32.jpg...
# 2023-04-15 00:37:24.839210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:24.839461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_13_0.jpg...
# 2023-04-15 00:37:25.137846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:25.138057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 275ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_11_0.jpg...
# 2023-04-15 00:37:25.463787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:25.464015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_18.jpg...
# 2023-04-15 00:37:25.766972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:25.767183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor14.JPG...
# 2023-04-15 00:37:26.102486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:26.102717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_35.jpg...
# 2023-04-15 00:37:26.406433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:26.406655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 249ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/ฉลามหูดำ​ 9166_230109_28_0.jpg...
# 2023-04-15 00:37:26.705539: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:26.705757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor01.jpg...
# 2023-04-15 00:37:27.001555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:27.001772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor03.JPG...
# 2023-04-15 00:37:27.335081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:37:27.335291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 261ms/step
# Processing ../dataset/splited/shark_44/test/spottail shark/C.sor (22).JPG...
# ...
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 277ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/T.obe02.jpg...
# 2023-04-15 00:38:07.570482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:07.570722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 263ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/T.obe01.jpg...
# 2023-04-15 00:38:07.876540: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:07.876789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 281ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/IMG_0169.JPG...
# 2023-04-15 00:38:08.292318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:08.292557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 268ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/IMG_0156.JPG...
# 2023-04-15 00:38:08.689213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:08.689435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 262ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/IMG_0146.JPG...
# 2023-04-15 00:38:09.097575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:09.097864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 308ms/step
# Processing ../dataset/splited/shark_44/test/whitetip reef shark/IMG_0152.JPG...
# 2023-04-15 00:38:09.549332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:09.549567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 293ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C. griseum.JPG...
# 2023-04-15 00:38:09.905895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:09.906132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 262ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_2377.JPG...
# 2023-04-15 00:38:10.373081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:10.373300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 287ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_2388.JPG...
# 2023-04-15 00:38:10.829461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:10.829681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 264ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C.gri11-1.jpg...
# 2023-04-15 00:38:11.200708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:11.200937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C.gri12.JPG...
# 2023-04-15 00:38:11.652440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:11.652670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 262ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C.gri06.JPG...
# 2023-04-15 00:38:11.989546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:11.989759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 254ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C.gri02.JPG...
# 2023-04-15 00:38:12.321602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:12.321831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 257ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C. griseum (6).JPG...
# 2023-04-15 00:38:12.640831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:12.641070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 252ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_4622.JPG...
# 2023-04-15 00:38:13.008269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:13.008482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 251ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_4626.JPG...
# 2023-04-15 00:38:13.390578: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:13.390798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 272ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_4625.JPG...
# 2023-04-15 00:38:13.787357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:13.787597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 277ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/IMG_2378.JPG...
# 2023-04-15 00:38:14.245062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:14.245291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 253ms/step
# Processing ../dataset/splited/shark_44/test/grey bambooshark/C. griseum (10).JPG...
# 2023-04-15 00:38:14.558743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:38:14.558978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [1,299,299,3]
# 	 [[{{node Placeholder/_10}}]]
# 1/1 [==============================] - 0s 255ms/step

# %%
y_test_label = encoder_labels.transform(y_test)

# %% [markdown]
# # DenseNet

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

ann_classifier = Sequential()
ann_classifier.add(Dense(1024, activation='relu', input_shape=(1920,)))
ann_classifier.add(Dropout(0.2))
ann_classifier.add(Dense(512, activation='relu'))
ann_classifier.add(Dropout(0.2))
ann_classifier.add(Dense(256, activation='relu'))
ann_classifier.add(Dropout(0.2))
ann_classifier.add(Dense(128, activation='relu'))
ann_classifier.add(Dense(18, activation='softmax'))

ann_classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = ann_classifier.fit(X_train, to_categorical(y_train), epochs=20, 
                             batch_size=32,
                             validation_data=(X_val, to_categorical(y_val)))

test_loss, test_acc = ann_classifier.evaluate(X_test, to_categorical(y_test_label, num_classes=18))
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/20
# 2023-04-15 00:51:44.704176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [645,1920]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:51:44.704438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 2s 41ms/step - loss: 2.5534 - accuracy: 0.2605 - val_loss: 2.0893 - val_accuracy: 0.3611
# Epoch 2/20
#  1/21 [>.............................] - ETA: 0s - loss: 1.7185 - accuracy: 0.5938
# 2023-04-15 00:51:46.158143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:51:46.158420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 1s 39ms/step - loss: 1.9629 - accuracy: 0.4062 - val_loss: 1.6396 - val_accuracy: 0.4722
# Epoch 3/20
# 21/21 [==============================] - 1s 42ms/step - loss: 1.5859 - accuracy: 0.4992 - val_loss: 1.4762 - val_accuracy: 0.5556
# Epoch 4/20
# 21/21 [==============================] - 1s 40ms/step - loss: 1.2857 - accuracy: 0.5984 - val_loss: 1.1964 - val_accuracy: 0.5694
# Epoch 5/20
# 21/21 [==============================] - 1s 38ms/step - loss: 1.0030 - accuracy: 0.6713 - val_loss: 0.9385 - val_accuracy: 0.7083
# Epoch 6/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.8392 - accuracy: 0.7442 - val_loss: 0.9766 - val_accuracy: 0.7083
# Epoch 7/20
# 21/21 [==============================] - 1s 41ms/step - loss: 0.6561 - accuracy: 0.7876 - val_loss: 1.0966 - val_accuracy: 0.7083
# Epoch 8/20
# 21/21 [==============================] - 1s 38ms/step - loss: 0.5626 - accuracy: 0.8372 - val_loss: 1.0305 - val_accuracy: 0.7222
# Epoch 9/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4690 - accuracy: 0.8450 - val_loss: 0.8184 - val_accuracy: 0.7917
# Epoch 10/20
# 21/21 [==============================] - 1s 43ms/step - loss: 0.4258 - accuracy: 0.8481 - val_loss: 0.9091 - val_accuracy: 0.7639
# Epoch 11/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3194 - accuracy: 0.9008 - val_loss: 0.8101 - val_accuracy: 0.8194
# Epoch 12/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2355 - accuracy: 0.9209 - val_loss: 0.6361 - val_accuracy: 0.8194
# Epoch 13/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2036 - accuracy: 0.9271 - val_loss: 0.6673 - val_accuracy: 0.8194
# Epoch 14/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1471 - accuracy: 0.9535 - val_loss: 0.5920 - val_accuracy: 0.8750
# Epoch 15/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1083 - accuracy: 0.9659 - val_loss: 0.6928 - val_accuracy: 0.8333
# Epoch 16/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1091 - accuracy: 0.9643 - val_loss: 0.5317 - val_accuracy: 0.8889
# Epoch 17/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1929 - accuracy: 0.9364 - val_loss: 0.5365 - val_accuracy: 0.8611
# Epoch 18/20
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1010 - accuracy: 0.9705 - val_loss: 0.8672 - val_accuracy: 0.8194
# Epoch 19/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1122 - accuracy: 0.9628 - val_loss: 0.5635 - val_accuracy: 0.8333
# Epoch 20/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0800 - accuracy: 0.9705 - val_loss: 0.5418 - val_accuracy: 0.8472
# 6/6 [==============================] - 0s 5ms/step - loss: 0.9332 - accuracy: 0.8245
# Test loss: 0.9332212805747986
# Test accuracy: 0.8244680762290955
# 2023-04-15 00:52:01.970843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [188,1920]
# 	 [[{{node Placeholder/_10}}]]
# 2023-04-15 00:52:01.971209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]

# %%
densenet_classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = densenet_classifier.fit(X_train, to_categorical(y_train), epochs=10, 
                        batch_size=32,
                        validation_data=(X_val, to_categorical(y_val)))
# Out:
# Epoch 1/10
# 2023-04-15 00:14:34.515493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:14:34.515772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 1s 18ms/step - loss: 2.2452 - accuracy: 0.3519 - val_loss: 1.6464 - val_accuracy: 0.5417
# Epoch 2/10
#  1/21 [>.............................] - ETA: 0s - loss: 1.2806 - accuracy: 0.7188
# 2023-04-15 00:14:35.250187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:14:35.250498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 0s 6ms/step - loss: 1.2833 - accuracy: 0.6496 - val_loss: 1.1446 - val_accuracy: 0.6806
# Epoch 3/10
# 21/21 [==============================] - 0s 7ms/step - loss: 0.8577 - accuracy: 0.7457 - val_loss: 0.9462 - val_accuracy: 0.7639
# Epoch 4/10
# 21/21 [==============================] - 0s 8ms/step - loss: 0.5862 - accuracy: 0.8574 - val_loss: 0.8399 - val_accuracy: 0.7778
# Epoch 5/10
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4219 - accuracy: 0.9085 - val_loss: 0.9180 - val_accuracy: 0.7639
# Epoch 6/10
# 21/21 [==============================] - 0s 10ms/step - loss: 0.3264 - accuracy: 0.9426 - val_loss: 0.7084 - val_accuracy: 0.7917
# Epoch 7/10
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2417 - accuracy: 0.9628 - val_loss: 0.6971 - val_accuracy: 0.8194
# Epoch 8/10
# 21/21 [==============================] - 0s 8ms/step - loss: 0.1893 - accuracy: 0.9721 - val_loss: 0.5982 - val_accuracy: 0.8333
# Epoch 9/10
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1394 - accuracy: 0.9845 - val_loss: 0.6410 - val_accuracy: 0.8333
# Epoch 10/10
# 21/21 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.9922 - val_loss: 0.6278 - val_accuracy: 0.8472

# %%
y_test_one_hot = to_categorical(y_test_label, num_classes=18)

test_loss, test_acc = densenet_classifier.evaluate(X_test, y_test_one_hot)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7398 - accuracy: 0.7766
# Test loss: 0.7398195266723633
# Test accuracy: 0.7765957713127136
# 2023-04-15 00:14:36.989053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:14:36.989357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]

# %%
densenet_classifier.save('../model/densenet_model.h5')

# %% [markdown]
# # CNN

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Reshape

cnn_classifier = Sequential()
cnn_classifier.add(Conv1D(64, 3, activation='relu', input_shape=(1920, 1)))
cnn_classifier.add(MaxPooling1D(2))
cnn_classifier.add(Conv1D(32, 3, activation='relu'))
cnn_classifier.add(MaxPooling1D(2))
cnn_classifier.add(Flatten())
cnn_classifier.add(Dense(256, activation='relu'))
cnn_classifier.add(Dense(18, activation='softmax'))

cnn_classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = cnn_classifier.fit(X_train, to_categorical(y_train), epochs=10, 
                        batch_size=32,
                        validation_data=(X_val, to_categorical(y_val)))

y_test_one_hot = to_categorical(y_test_label, num_classes=18)

test_loss, test_acc = cnn_classifier.evaluate(X_test, y_test_one_hot)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 2023-04-15 00:42:35.441655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:42:35.441924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 3s 105ms/step - loss: 2.4417 - accuracy: 0.2620 - val_loss: 1.9524 - val_accuracy: 0.4444
# Epoch 2/10
# 2023-04-15 00:42:38.144094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:42:38.144370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 21/21 [==============================] - 2s 97ms/step - loss: 1.5238 - accuracy: 0.5581 - val_loss: 1.2705 - val_accuracy: 0.6944
# Epoch 3/10
# 21/21 [==============================] - 2s 117ms/step - loss: 0.8008 - accuracy: 0.7566 - val_loss: 0.8543 - val_accuracy: 0.7639
# Epoch 4/10
# 21/21 [==============================] - 2s 92ms/step - loss: 0.4027 - accuracy: 0.8961 - val_loss: 0.8805 - val_accuracy: 0.7778
# Epoch 5/10
# 21/21 [==============================] - 2s 100ms/step - loss: 0.2252 - accuracy: 0.9333 - val_loss: 1.1028 - val_accuracy: 0.7500
# Epoch 6/10
# 21/21 [==============================] - 2s 100ms/step - loss: 0.1770 - accuracy: 0.9612 - val_loss: 0.7882 - val_accuracy: 0.7917
# Epoch 7/10
# 21/21 [==============================] - 2s 92ms/step - loss: 0.0589 - accuracy: 0.9876 - val_loss: 0.8503 - val_accuracy: 0.8056
# Epoch 8/10
# 21/21 [==============================] - 2s 106ms/step - loss: 0.0322 - accuracy: 0.9922 - val_loss: 1.0561 - val_accuracy: 0.8056
# Epoch 9/10
# 21/21 [==============================] - 2s 116ms/step - loss: 0.0230 - accuracy: 0.9953 - val_loss: 0.8953 - val_accuracy: 0.8333
# Epoch 10/10
# 21/21 [==============================] - 3s 119ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.8192 - val_accuracy: 0.8472
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1005 - accuracy: 0.7713
# Test loss: 1.1005252599716187
# Test accuracy: 0.771276593208313
# 2023-04-15 00:42:58.092053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:42:58.092338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]

# %%
X_test.shape
# Out:
# (188, 1920)

# %%
y_train.shape
# Out:
# (645,)

# %% [markdown]
# # RNN

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Reshape

rnn_classifier = Sequential()
rnn_classifier.add(Reshape((1920, 1), input_shape=(1920,)))
rnn_classifier.add(LSTM(64, return_sequences=True))
rnn_classifier.add(LSTM(32))
rnn_classifier.add(Dense(256, activation='relu'))
rnn_classifier.add(Dense(18, activation='softmax'))

rnn_classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = rnn_classifier.fit(X_train, to_categorical(y_train), epochs=10, 
                        batch_size=32,
                        validation_data=(X_val, to_categorical(y_val)))

y_test_one_hot = to_categorical(y_test_label, num_classes=18)

test_loss, test_acc = rnn_classifier.evaluate(X_test, y_test_one_hot)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 2023-04-15 00:46:45.514142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:45.515409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:45.516986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-15 00:46:45.676444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:45.677327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:45.678384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/10
# 2023-04-15 00:46:45.741804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:46:45.742115: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [645,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:46:45.963496: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:45.965412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:45.966717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-15 00:46:46.131851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:46.133382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:46.134572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-15 00:46:46.977354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:46.978392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:46.979442: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-15 00:46:47.140677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:46:47.141727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:46:47.142798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 21/21 [==============================] - ETA: 0s - loss: 2.7450 - accuracy: 0.1969
# 2023-04-15 00:47:11.002648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:47:11.002920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [72,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:47:11.197291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:47:11.198390: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:47:11.199471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-15 00:47:11.359124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-15 00:47:11.360140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-15 00:47:11.361113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 21/21 [==============================] - 26s 1s/step - loss: 2.7450 - accuracy: 0.1969 - val_loss: 2.6881 - val_accuracy: 0.2222
# Epoch 2/10
# 21/21 [==============================] - 22s 1s/step - loss: 2.6251 - accuracy: 0.2031 - val_loss: 2.6513 - val_accuracy: 0.2222
# Epoch 3/10
# 21/21 [==============================] - 22s 1s/step - loss: 2.6098 - accuracy: 0.2047 - val_loss: 2.6513 - val_accuracy: 0.1944
# Epoch 4/10
# 21/21 [==============================] - 22s 1s/step - loss: 2.6035 - accuracy: 0.2016 - val_loss: 2.6442 - val_accuracy: 0.2222
# Epoch 5/10
# 21/21 [==============================] - 26s 1s/step - loss: 2.5928 - accuracy: 0.2031 - val_loss: 2.6367 - val_accuracy: 0.2361
# Epoch 6/10
# 21/21 [==============================] - 27s 1s/step - loss: 2.5859 - accuracy: 0.2093 - val_loss: 2.6333 - val_accuracy: 0.2222
# Epoch 7/10
# 21/21 [==============================] - 23s 1s/step - loss: 2.5697 - accuracy: 0.2202 - val_loss: 2.5975 - val_accuracy: 0.2083
# Epoch 8/10
# 21/21 [==============================] - 23s 1s/step - loss: 2.5399 - accuracy: 0.2295 - val_loss: 2.5653 - val_accuracy: 0.2361
# Epoch 9/10
# 21/21 [==============================] - 23s 1s/step - loss: 2.5282 - accuracy: 0.2388 - val_loss: 2.5949 - val_accuracy: 0.2083
# Epoch 10/10
# 21/21 [==============================] - 24s 1s/step - loss: 2.5105 - accuracy: 0.2434 - val_loss: 2.6273 - val_accuracy: 0.1806
# 2023-04-15 00:50:44.023087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]
# 2023-04-15 00:50:44.023373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [188,18]
# 	 [[{{node Placeholder/_11}}]]
# 6/6 [==============================] - 2s 249ms/step - loss: 2.5593 - accuracy: 0.2340
# Test loss: 2.559300184249878
# Test accuracy: 0.23404255509376526

# %% [markdown]
# # SVC

# %%
clf = SVC(kernel='rbf', probability=True)

# %%
param_grid = {'gamma': [0.001, 0.01, 0.1, 1, 10],
              'C': [0.001, 0.01, 0.1, 1, 10]}

svc = SVC(kernel='rbf')

# perform grid search to find best gamma and C values
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5)
grid_search.fit(X_val, y_val)

best_gamma = grid_search.best_params_['gamma']
best_C = grid_search.best_params_['C']

print("Best gamma value:", grid_search.best_params_['gamma'])
print("Best C value:", grid_search.best_params_['C'])
print("Accuracy score:", grid_search.best_score_)
# Out:
# Best gamma value: 0.001
# Best C value: 10
# Accuracy score: 0.5161904761904761

# %%
clf.set_params(C=best_C)
clf.set_params(gamma=best_gamma)
clf.fit(X_train, y_train)

train_accuracy = clf.score(X_train, y_train)
val_accuracy = clf.score(X_val, y_val)
y_test_num = encoder_labels.transform(y_test)
test_accuracy = clf.score(X_test, y_test_label)

print("Accuracy on training data:", train_accuracy)
print("Accuracy on validation data:", val_accuracy)
print("Accuracy on testing data:", test_accuracy)
# Out:
# Accuracy on training data: 0.9984496124031008
# Accuracy on validation data: 0.8611111111111112
# Accuracy on testing data: 0.8031914893617021

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test_label, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         8
#            1       0.50      0.67      0.57         6
#            2       0.78      0.88      0.82         8
#            3       1.00      0.50      0.67         2
#            4       1.00      0.60      0.75         5
#            5       1.00      0.50      0.67         2
#            6       0.92      0.85      0.88        13
#            7       0.56      0.71      0.63         7
#            8       1.00      0.92      0.96        12
#            9       0.70      0.93      0.80        28
#           10       0.80      0.89      0.84         9
#           11       0.88      1.00      0.93         7
#           12       0.80      0.44      0.57         9
#           13       0.77      0.81      0.79        37
#           14       1.00      0.86      0.92         7
#           15       1.00      1.00      1.00        11
#           16       1.00      0.78      0.88         9
#           17       1.00      0.62      0.77         8
#
#     accuracy                           0.80       188
#    macro avg       0.85      0.75      0.78       188
# weighted avg       0.82      0.80      0.80       188

# %%
joblib.dump(clf, '../model/svc_model.pkl')
# Out:
# ['../model/svc_model.pkl']

# %% [markdown]
# # KNN

# %%
clf = KNeighborsClassifier()

param_grid = {'n_neighbors': [1, 3, 5, 7, 9]}

knn = KNeighborsClassifier()

grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5)
grid_search.fit(X_val, y_val)

best_n_neighbors = grid_search.best_params_['n_neighbors']

print("Best n_neighbors value:", best_n_neighbors)
print("Accuracy score:", grid_search.best_score_)

clf.set_params(n_neighbors=best_n_neighbors)
clf.fit(X_train, y_train)

train_accuracy = clf.score(X_train, y_train)
val_accuracy = clf.score(X_val, y_val)
y_test_num = encoder_labels.transform(y_test)
test_accuracy = clf.score(X_test, y_test_label)

print("Accuracy on training data:", train_accuracy)
print("Accuracy on validation data:", val_accuracy)
print("Accuracy on testing data:", test_accuracy)

joblib.dump(clf, '../model/knn_model.pkl')
# Out:
# Best n_neighbors value: 1
# Accuracy score: 0.5580952380952381
# Accuracy on training data: 1.0
# Accuracy on validation data: 0.8472222222222222
# Accuracy on testing data: 0.776595744680851
# ['../model/knn_model.pkl']

# %% [markdown]
# # GaussainNB

# %%
# create a Gaussian Naive Bayes classifier
clf = GaussianNB()

# fit the classifier to the training data
clf.fit(X_train, y_train)

# make predictions on the training, validation, and test sets
train_preds = clf.predict(X_train)
val_preds = clf.predict(X_val)
test_preds = clf.predict(X_test)

test_preds_label = encoder_labels.inverse_transform(test_preds)


# calculate accuracy scores for the predictions
train_accuracy = accuracy_score(y_train, train_preds)
val_accuracy = accuracy_score(y_val, val_preds)
test_accuracy = accuracy_score(y_test, test_preds_label)

print(y_test)

print("Accuracy on training data:", train_accuracy)
print("Accuracy on validation data:", val_accuracy)
print("Accuracy on testing data:", test_accuracy)
# Out:
# ['grey reef shark', 'grey reef shark', 'grey reef shark', 'grey reef shark', 'grey reef shark', 'grey reef shark', 'grey reef shark', 'great hammerhead', 'great hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'scalloped hammerhead', 'coral shark', 'coral shark', 'bull shark', 'bull shark', 'bull shark', 'bull shark', 'bull shark', 'bull shark', 'bull shark', 'bull shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'spottail shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'pigeye shark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'whitespotted bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'indonesian bambooshark', 'zebra shark', 'zebra shark', 'zebra shark', 'zebra shark', 'zebra shark', 'zebra shark', 'zebra shark', 'zebra shark', 'tiger shark', 'tiger shark', 'tiger shark', 'tiger shark', 'tiger shark', 'tiger shark', 'tiger shark', 'slender bambooshark', 'slender bambooshark', 'slender bambooshark', 'slender bambooshark', 'slender bambooshark', 'slender bambooshark', 'slender bambooshark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'blacktip reef shark', 'graceful shark', 'graceful shark', 'graceful shark', 'graceful shark', 'graceful shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'spinner shark', 'brownbanded shark', 'brownbanded shark', 'brownbanded shark', 'brownbanded shark', 'brownbanded shark', 'brownbanded shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'whitetip reef shark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark', 'grey bambooshark']
# Accuracy on training data: 0.8728682170542635
# Accuracy on validation data: 0.7083333333333334
# Accuracy on testing data: 0.6968085106382979

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# define the model
clf = RandomForestClassifier()

# define the parameter grid to search over
param_grid = {'n_estimators': [100, 200, 300, 400],
              'max_depth': [None, 5, 10, 20],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# perform grid search to find best hyperparameters
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5)
grid_search.fit(X_val, y_val)

best_n_estimators = grid_search.best_params_['n_estimators']
best_max_depth = grid_search.best_params_['max_depth']
best_min_samples_split = grid_search.best_params_['min_samples_split']
best_min_samples_leaf = grid_search.best_params_['min_samples_leaf']

print("Best n_estimators value:", best_n_estimators)
print("Best max_depth value:", best_max_depth)
print("Best min_samples_split value:", best_min_samples_split)
print("Best min_samples_leaf value:", best_min_samples_leaf)
print("Accuracy score:", grid_search.best_score_)

# train the model on the whole training set using the best hyperparameters
clf.set_params(n_estimators=best_n_estimators)
clf.set_params(max_depth=best_max_depth)
clf.set_params(min_samples_split=best_min_samples_split)
clf.set_params(min_samples_leaf=best_min_samples_leaf)
clf.fit(X_train, y_train)

# evaluate the performance of the model on the train, validation, and test sets
train_accuracy = accuracy_score(y_train, clf.predict(X_train))
val_accuracy = accuracy_score(y_val, clf.predict(X_val))
test_accuracy = accuracy_score(y_test, encoder_labels.inverse_transform(clf.predict(X_test)))

print("Accuracy on training data:", train_accuracy)
print("Accuracy on validation data:", val_accuracy)
print("Accuracy on testing data:", test_accuracy)
# Out:
# Best n_estimators value: 200
# Best max_depth value: 10
# Best min_samples_split value: 2
# Best min_samples_leaf value: 1
# Accuracy score: 0.47523809523809524
# Accuracy on training data: 1.0
# Accuracy on validation data: 0.75
# Accuracy on testing data: 0.648936170212766

# %% [markdown]
# # SGDClassifier

# %%
clf = SGDClassifier(loss='log_loss', max_iter=1000, tol=1e-3)

# %%
clf.set_params(alpha=best_alpha)
clf.set_params(penalty=best_penalty)
clf.set_params(l1_ratio=best_l1_ratio)
clf.fit(X_train, y_train)

# %%
train_losses = []
val_losses = []
test_losses = []
for i in range(10):
    clf.partial_fit(X_train, y_train, classes=np.unique(y_train))
    train_pred = clf.predict_proba(X_train)
    train_loss = log_loss(y_train, train_pred, labels=clf.classes_)
    val_pred = clf.predict_proba(X_val)
    val_loss = log_loss(y_val, val_pred, labels=clf.classes_)
    train_losses.append(train_loss)
    val_losses.append(val_loss)

train_accuracy = clf.score(X_train, y_train)
val_accuracy = clf.score(X_val, y_val)
test_accuracy = clf.score(X_test, y_test_label)

print("Accuracy on training data: {:.3f}".format(train_accuracy))
print("Average training loss: {:.3f}".format(np.mean(train_losses)))
print("Accuracy on validation data: {:.3f}".format(val_accuracy))
print("Average validation loss: {:.3f}".format(np.mean(val_losses)))
print("Accuracy on testing data: {:.3f}".format(test_accuracy))

# %%
joblib.dump(clf, '../model/sgd_model.pkl')

# %% [markdown]
# # Avenger Ensemble

# %%
model_1 = load_model('../model/v1/densenet_model.h5')
model_2 = joblib.load('../model/v1/svc_model.pkl')
model_3 = joblib.load('../model/v1/sgd_model.pkl')

# %%
models = [model_1, model_2, model_3]

# %%
predictions = []
for model in models:
    pred = model.predict(X_test)
    if len(pred.shape) == 1:  
        pred_onehot = np.zeros((len(pred), 18))  
        pred_onehot[np.arange(len(pred)), pred] = 1  
        predictions.append(pred_onehot)
    else:  
        predictions.append(pred)

predictions = np.array(predictions)
summed = np.sum(predictions, axis=0)
ensemble_prediction = np.argmax(summed, axis=1)

# %%
# get the predicted classes
pred_classes1 = np.argmax(predictions[0], axis=1)
pred_classes2 = np.argmax(predictions[1], axis=1)
pred_classes3 = np.argmax(predictions[2], axis=1)

# %% [markdown]
# # Average ensemble

# %%
accuracy1 = accuracy_score(y_test_label, pred_classes1)
accuracy2 = accuracy_score(y_test_label, pred_classes2)
accuracy3 = accuracy_score(y_test_label, pred_classes3)
ensemble_accuracy = accuracy_score(y_test_label, ensemble_prediction)

val_accuracies = [accuracy1, accuracy2, accuracy3]

print('Accuracy Score for model 1 = ', accuracy1)
print('Accuracy Score for model 2 = ', accuracy2)
print('Accuracy Score for model 3 = ', accuracy3)
print('Accuracy Score for average ensemble = ', ensemble_accuracy)

# %% [markdown]
# # Weight Average Ensemble

# %%
weights = [acc / sum(val_accuracies) for acc in val_accuracies]

weighted_preds = np.tensordot(predictions, weights, axes=((0),(0)))
weighted_ensemble_prediction = np.argmax(weighted_preds, axis=1)

weighted_accuracy = accuracy_score(y_test_label, weighted_ensemble_prediction)

print('Accuracy Score for model1 = ', accuracy1)
print('Accuracy Score for model2 = ', accuracy2)
print('Accuracy Score for model3 = ', accuracy3)
print('Accuracy Score for average ensemble = ', ensemble_accuracy)
print('Accuracy Score for weighted average ensemble = ', weighted_accuracy)

# %% [markdown]
# # Find Best Weight

# %%
df = pd.DataFrame([])

for w1 in range(1, 11):
    for w2 in range(1, 11):
        for w3 in range(1, 11):
            # normalize weights to sum to 1
            total_weight = w1 + w2 + w3
            if total_weight == 0:
                continue
            wts = [w1/total_weight, w2/total_weight, w3/total_weight]

            # get weighted predictions and calculate accuracy
            wted_preds = np.tensordot(predictions, wts, axes=((0),(0)))
            wted_ensemble_pred = np.argmax(wted_preds, axis=1)
            weighted_accuracy = accuracy_score(y_test_label, wted_ensemble_pred)

            # add results to dataframe
            df = pd.concat([df, pd.DataFrame({'wt1': wts[0], 'wt2': wts[1], 
                                               'wt3': wts[2], 
                                               'acc': weighted_accuracy*100}, index=[0])],
                                               ignore_index=True)
            
# find the row with the highest accuracy
max_acc_row = df.iloc[df['acc'].idxmax()]

# print the results
print("Max accuracy of ", max_acc_row['acc'], " obtained with w1=", max_acc_row['wt1'],
      " w2=", max_acc_row['wt2'], " w3=", max_acc_row['wt3'])

# %%
best_weights = [0.25, 0.5, 0.25]

ideal_weighted_preds = np.tensordot(predictions, best_weights, axes=((0),(0)))
ideal_weighted_ensemble_prediction = np.argmax(ideal_weighted_preds, axis=1)
ideal_weighted_accuracy = accuracy_score(y_test_label, ideal_weighted_ensemble_prediction)

i = random.choice(ideal_weighted_ensemble_prediction)

print("Predicted Label: ", class_labels[int(ideal_weighted_ensemble_prediction[i])])
print("True Label: ", class_labels[int(y_test_label[i])])

#Print confusion matrix
cm = confusion_matrix(y_test_label, ideal_weighted_ensemble_prediction)

fig, ax = plt.subplots(figsize=(12,12))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)


incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
fig, ax = plt.subplots(figsize=(50,5))
plt.bar(np.arange(18), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.xticks(np.arange(18), class_labels)

# %% [markdown]
# # For the BOT

# %%
def extract_feature_no_bg(list_images):
    data = []
    labels = []

    nb_features = 1920  
    features = np.empty((len(list_images), nb_features))

    for ind, img_path in enumerate(list_images):
        print('Processing image %s...' % (img_path))
        img = image.load_img(img_path, target_size=(299, 299))
        output1 = remove(img)
        output2 = output1.convert('RGB')
        x = image.img_to_array(output2)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        features[ind,:] = np.squeeze(extractor_model.predict(x))
        labels.append(img_path.split('/')[-2])
    
    return features, labels

# %%
def predict_ensemble(features):
    preds_1 = model_1.predict(features)
    sorted_preds1 = np.sort(preds_1)
    top_preds1 = sorted_preds1[0][-1:-3:-1]
    sorted_idx1 = np.argsort(preds_1)
    top_label1 = sorted_idx1[0][-1:-4:-1]
    
    preds_2 = model_2.predict(features)
    preds_prob_2 = model_2.predict_proba(features)
    sorted_preds2 = np.sort(preds_prob_2)
    top_preds2 = sorted_preds2[0][-1:-3:-1]
    sorted_idx2 = np.argsort(preds_prob_2)
    top_label2 = sorted_idx2[0][-1:-4:-1]

    preds_3 = model_3.predict(features)
    preds_prob_3 = model_3.predict_proba(features)
    sorted_preds3 = np.sort(preds_prob_3)
    top_preds3 = sorted_preds3[0][-1:-3:-1]
    sorted_idx3 = np.argsort(preds_prob_3)
    top_label3 = sorted_idx3[0][-1:-4:-1]

    # Apply the best weight values to the predicted outputs of each model
    weighted_preds_1 = preds_1 * best_weights[0]
    weighted_preds_2 = preds_2 * best_weights[1]
    weighted_preds_3 = preds_3 * best_weights[2]
    
    final_preds = np.argmax(weighted_preds_1 + weighted_preds_2 + weighted_preds_3, axis=1)
    final_preds_label = encoder_labels.inverse_transform(final_preds)
    
    print('Top 3 class for Model 1:', top_label1)
    print('Top 3 class for Model 2:', top_label2)
    print('Top 3 class for Model 3:', top_label3)
    
    return final_preds

# %%
def final_answer(pred1, pred2):
    if pred1 == pred2:
        p1 = encoder_labels.inverse_transform(pred1)[0]
        return p1
    else:
        p1 = encoder_labels.inverse_transform(pred1)[0]
        p2 = encoder_labels.inverse_transform(pred2)[0]
        return p1,p2

# %%
image_path = ['../dataset/pigeye.jpeg']
features, labels = extract_feature(image_path)
img_pred_class1 = predict_ensemble(features)

features2, labels2 = extract_feature_no_bg(image_path)
img_pred_class2 = predict_ensemble(features2)

if img_pred_class2[0] == "N" and img_pred_class1[0] == "N":
    print("Can you use Diffrenet Images")
    
elif img_pred_class2[0] == "Y" and img_pred_class1[0] == "N":
    print("Can you use Diffrenet Images")
    
else:
    x = final_answer(img_pred_class1[1], img_pred_class2[1])
    print(x)
    exit()

# %% [markdown]
# ## GRAVEYARD

# %%
# encoder_labels.inverse_transform([img_pred_class])

# %%
model_1.summary()

# %%
model_2.get_params()

# %%
model_3.get_params()

# %%
def predict_ensemble(features):
    preds_1 = model_1.predict(features)
    sorted_preds1 = np.sort(preds_1)
    top_preds1 = sorted_preds1[0][-1:-3:-1]
    sorted_idx1 = np.argsort(preds_1)
    top_label1 = sorted_idx1[0][-1:-4:-1]

    preds_2 = model_2.predict(features)
    preds_prob_2 = model_2.predict_proba(features)
    sorted_preds2 = np.sort(preds_prob_2)
    top_preds2 = sorted_preds2[0][-1:-3:-1]
    sorted_idx2 = np.argsort(preds_prob_2)
    top_label2 = sorted_idx2[0][-1:-4:-1]

    preds_3 = model_3.predict(features)
    preds_prob_3 = model_3.predict_proba(features)
    sorted_preds3 = np.sort(preds_prob_3)
    top_preds3 = sorted_preds3[0][-1:-3:-1]
    sorted_idx3 = np.argsort(preds_prob_3)
    top_label3 = sorted_idx3[0][-1:-4:-1]

    # Apply the best weight values to the predicted outputs of each model
    weighted_preds_1 = preds_1 * best_weights[0]
    weighted_preds_2 = preds_2 * best_weights[1]
    weighted_preds_3 = preds_3 * best_weights[2]

    final_preds = np.argmax(
        weighted_preds_1 + weighted_preds_2 + weighted_preds_3, axis=1)
    final_preds_label = encoder_labels.inverse_transform(final_preds)

    print('Top 3 class for Model 1:', top_label1)
    print('Top 3 class for Model 2:', top_label2)
    print('Top 3 class for Model 3:', top_label3)
    
    return final_preds

image_path = ['../dataset/pigeye.jpeg']
features, labels = extract_feature(image_path)
img_pred_class1 = predict_ensemble(features)

features2, labels2 = extract_feature_no_bg(image_path)
img_pred_class2 = predict_ensemble(features2)

x = final_answer(img_pred_class1, img_pred_class2)
